# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
f = open('../../final.csv','r')
final = pd.read_csv(f)

# %%
final=final[final.Open_int==1]

# %%
mes1=final[final.mes==1]
mes2=final[final.mes==2]
mes3=final[final.mes==3]
mes4=final[final.mes==4]
mes5=final[final.mes==5]
mes6=final[final.mes==6]
mes7=final[final.mes==7]
mes8=final[final.mes==8]
mes9=final[final.mes==9]
mes10=final[final.mes==10]
mes11=final[final.mes==11]
mes12=final[final.mes==12]

# %%
mes1.to_csv('mes1.csv')
mes2.to_csv('mes2.csv')
mes3.to_csv('mes3.csv')
mes4.to_csv('mes4.csv')
mes5.to_csv('mes5.csv')
mes6.to_csv('mes6.csv')
mes7.to_csv('mes7.csv')
mes8.to_csv('mes8.csv')
mes9.to_csv('mes9.csv')
mes10.to_csv('mes10.csv')
mes11.to_csv('mes11.csv')
mes12.to_csv('mes12.csv')
# Out:
#          Unnamed: 0  Store  Promo2  tipo_store_a  tipo_store_b  tipo_store_c  \
# 181             181      1       0             0             0             1
# 182             182      1       0             0             0             1
# 183             183      1       0             0             0             1
# 184             184      1       0             0             0             1
# 185             185      1       0             0             0             1
# 186             186      1       0             0             0             1
# 188             188      1       0             0             0             1
# 189             189      1       0             0             0             1
# 190             190      1       0             0             0             1
# 191             191      1       0             0             0             1
# 192             192      1       0             0             0             1
# ...
